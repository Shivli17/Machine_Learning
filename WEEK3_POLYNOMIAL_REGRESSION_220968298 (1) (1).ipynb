# %% [markdown]
# ## Name- Shivli Mathur
# ## Reg. no.-220968298
# ## Batch-B4
# ## Week-3

# %% [markdown]
# ## POLYNOMIAL_REGRESSION

# %% [markdown]
# ### For mtcars dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mtcars.csv")
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
x=df[["hp"]]
y=df["disp"]

# %%
df['hp'].corr(df['disp'])
# Out:
# 0.7909485863698065

# %%
x
# Out:
#      hp
# 0   110
# 1   110
# 2    93
# 3   110
# 4   175
# 5   105
# 6   245
# 7    62
# 8    95
# 9   123
# 10  123
# 11  180
# 12  180
# 13  180
# 14  205
# 15  215
# 16  230
# 17   66
# 18   52
# 19   65
# 20   97
# 21  150
# 22  150
# 23  245
# 24  175
# 25   66
# 26   91
# 27  113
# 28  264
# 29  175
# 30  335
# 31  109

# %%
y
# Out:
# 0     160.0
# 1     160.0
# 2     108.0
# 3     258.0
# 4     360.0
# 5     225.0
# 6     360.0
# 7     146.7
# 8     140.8
# 9     167.6
# 10    167.6
# 11    275.8
# 12    275.8
# 13    275.8
# 14    472.0
# 15    460.0
# 16    440.0
# 17     78.7
# 18     75.7
# 19     71.1
# 20    120.1
# 21    318.0
# 22    304.0
# 23    350.0
# 24    400.0
# 25     79.0
# 26    120.3
# 27     95.1
# 28    351.0
# 29    145.0
# 30    301.0
# 31    121.0
# Name: disp, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4,include_bias=False)
poly.fit(x_train,y_train)
x_poly_train=poly.transform(x_train)
x_poly_test=poly.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_poly_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_poly_test)
y_pred
# Out:
# array([323.7558781 , 262.99486488, 198.8319377 , 132.07903145,
#        375.12423416, 358.39651586, 369.36961324, 128.28491825,
#        140.00383663, 323.7558781 ])

# %%
y_test
# Out:
# 11    275.8
# 22    304.0
# 10    167.6
# 2     108.0
# 16    440.0
# 14    472.0
# 28    351.0
# 26    120.3
# 20    120.1
# 13    275.8
# Name: disp, dtype: float64

# %%
model.intercept_
# Out:
# 224.61330090894774

# %%
model.coef_
# Out:
# array([-5.75309271e+00,  7.35809811e-02, -2.69752884e-04,  3.08522232e-07])

# %%
plt.scatter(x_test, y_test)
sns.lineplot(x=x_test.values.reshape(-1,), y=y_pred)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import math
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 2574.8168208252523
# Root_Mean_Squared_Error: 50.74265287532031
# Mean_Absolute_Error: 41.69654785729096

# %% [markdown]
# ### For diabetes dataset

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df["DiabetesPedigreeFunction"] = df["Insulin"].replace(0, pd.NaT)
df["Insulin"] = df["Insulin"].replace(0, pd.NaT)

# %%
x=df[["Insulin"]]
y=df["DiabetesPedigreeFunction"]

# %%
x=x.dropna()
x
# Out:
#     Insulin
# 3        94
# 4       168
# 6        88
# 8       543
# 13      846
# ..      ...
# 753     510
# 755     110
# 760      16
# 763     180
# 765     112
#
# [394 rows x 1 columns]

# %%
y=y.dropna()
y
# Out:
# 3       94
# 4      168
# 6       88
# 8      543
# 13     846
#       ...
# 753    510
# 755    110
# 760     16
# 763    180
# 765    112
# Name: DiabetesPedigreeFunction, Length: 394, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
model = LinearRegression()

# %%
poly = PolynomialFeatures(degree=2,include_bias=False)
poly.fit(x_train,y_train)
x_poly_train=poly.transform(x_train)
x_poly_test=poly.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_poly_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_poly_test)
y_pred
# Out:
# array([370.,  76.,  63., 148., 105.,  95.,  92., 130.,  89.,  70.,  51.,
#         57., 215., 112., 205.,  95., 215.,  94., 135., 156.,  46., 180.,
#         94., 105., 185., 110., 155., 158., 278.,  50., 106., 280., 210.,
#         53., 156., 194.,  37., 510.,  56., 230., 168.,  44., 105., 160.,
#        105.,  55., 120., 180.,  44., 478., 325., 146., 110.,  40.,  66.,
#        126., 110.,  84.,  74., 145.,  54.,  41.,  79., 175., 140., 180.,
#         83.,  74.,  82.,  94., 328., 105., 105.,  94.,  58., 375., 140.,
#        100., 330., 170., 360.,  76., 440., 110., 100.,  96., 249.,  29.,
#         63.,  50.,  40.,  71.,  49.,  36., 230., 215.,  78., 231., 130.,
#        277.,  75., 495., 105.,  36.,  52., 144., 171.,  36.,  85., 116.,
#        160., 225., 115., 210.,  58., 155.,  23., 125.,  91.])

# %%
y_test
# Out:
# 231    370
# 544     76
# 142     63
# 311    148
# 640    105
#       ...
# 334     58
# 282    155
# 52      23
# 693    125
# 638     91
# Name: DiabetesPedigreeFunction, Length: 119, dtype: object

# %%
model.intercept_
# Out:
# 2.842170943040401e-14

# %%
model.coef_
# Out:
# array([ 1.00000000e+00, -1.82731936e-19])

# %%
plt.scatter(x_test, y_test)
sns.lineplot(x=x_test.values.reshape(-1,), y=y_pred)
plt.show()

# %%
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 6.111484417994581e-28
# Root_Mean_Squared_Error: 2.4721416662470177e-14
# Mean_Absolute_Error: 1.3792888400049004e-14

# %% [markdown]
# ### For winequality-red dataset

# %%
df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
x=df[["alcohol"]]
y=df["quality"]

# %%
x
# Out:
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1138     11.0
# 1139      9.5
# 1140     10.5
# 1141     11.2
# 1142     10.2
#
# [1143 rows x 1 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
model = LinearRegression()

# %%
poly = PolynomialFeatures(degree=3,include_bias=False)
poly.fit(x_train,y_train)
x_poly_train=poly.transform(x_train)
x_poly_test=poly.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_poly_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_poly_test)
y_pred
# Out:
# array([5.33829175, 6.06561711, 5.18489236, 5.65036646, 5.30426484,
#        5.65036646, 5.3737308 , 5.86157658, 6.06561711, 5.4104513 ,
#        5.27178076, 6.06561711, 5.77703807, 5.24097019, 6.21270977,
#        5.18489236, 5.77703807, 5.21196383, 5.18489236, 5.48721393,
#        5.52699469, 5.30426484, 5.30426484, 5.30426484, 5.27178076,
#        5.11659414, 5.21196383, 5.86157658, 5.98590674, 5.4104513 ,
#        5.30426484, 5.56753415, 5.98590674, 5.4104513 , 5.33829175,
#        5.81938537, 6.06561711, 5.44832258, 5.21196383, 6.02616669,
#        5.4104513 , 6.30812555, 5.52699469, 6.06561711, 5.3737308 ,
#        5.27178076, 5.30426484, 5.81938537, 6.21270977, 6.33639502,
#        5.48721393, 5.94496795, 5.69239793, 6.27800106, 5.30426484,
#        5.21196383, 5.48721393, 5.24097019, 5.27178076, 5.98590674,
#        5.77703807, 5.18489236, 5.3737308 , 5.4104513 , 5.48721393,
#        5.27178076, 6.38684614, 5.21196383, 5.60870164, 5.69239793,
#        5.30426484, 5.52699469, 5.65036646, 6.30812555, 6.06561711,
#        6.36267878, 6.24615224, 6.10412732, 5.48721393, 6.14156662,
#        5.18489236, 5.86157658, 5.69239793, 5.24097019, 6.27800106,
#        5.48721393, 5.903481  , 5.33829175, 5.48721393, 5.3737308 ,
#        6.06561711, 6.27800106, 5.903481  , 5.33829175, 5.24097019,
#        5.33829175, 5.44832258, 5.27178076, 5.24097019, 5.44832258,
#        5.86157658, 5.48721393, 6.40876642, 5.30426484, 5.3737308 ,
#        5.77703807, 5.56753415, 6.10412732, 5.33829175, 5.27178076,
#        5.27178076, 6.02616669, 5.4104513 , 6.21270977, 5.30426484,
#        5.81938537, 5.3737308 , 5.98590674, 5.44832258, 6.27800106,
#        5.60870164, 5.18489236, 5.11659414, 6.47136298, 6.06561711,
#        5.09856908, 5.903481  , 6.40876642, 5.30426484, 6.06561711,
#        6.21270977, 6.44534298, 5.30426484, 5.4104513 , 5.15988646,
#        5.21196383, 5.3737308 , 6.38684614, 5.56753415, 5.4104513 ,
#        5.69239793, 6.14156662, 5.44832258, 5.903481  , 5.52699469,
#        5.15988646, 5.86157658, 5.81938537, 6.36267878, 5.3737308 ,
#        5.4104513 , 5.69239793, 6.36267878, 5.77703807, 5.21196383,
#        5.52699469, 5.33829175, 6.24615224, 5.24097019, 6.17780433,
#        5.33829175, 5.86157658, 5.24097019, 5.27178076, 5.33829175,
#        5.94496795, 6.06561711, 6.36267878, 5.98590674, 5.48721393,
#        5.3737308 , 5.3737308 , 5.33829175, 5.69239793, 6.06561711,
#        5.81938537, 5.60870164, 5.21196383, 5.24097019, 6.10412732,
#        5.21196383, 5.27178076, 5.24097019, 5.4104513 , 5.30426484,
#        5.52699469, 5.21196383, 5.27178076, 5.21196383, 5.903481  ,
#        6.27800106, 5.30426484, 5.33829175, 5.60870164, 6.42830893,
#        5.3737308 , 5.65036646, 5.73466536, 5.30426484, 5.60870164,
#        5.73466536, 5.903481  , 5.48721393, 5.98590674, 6.36267878,
#        5.903481  , 5.27178076, 5.86157658, 5.07041463, 5.60870164,
#        5.86157658, 5.81938537, 5.81938537, 6.21270977, 5.27178076,
#        5.27178076, 5.50038182, 5.52699469, 5.4104513 , 5.69239793,
#        5.86157658, 5.48721393, 5.22142409, 5.48721393, 5.69239793,
#        6.10412732, 6.42830893, 5.33829175, 5.33829175, 5.903481  ,
#        5.48721393, 5.69239793, 5.30426484, 5.69239793, 5.73466536,
#        5.52699469, 6.48755131, 5.30426484, 5.21196383, 5.56753415,
#        6.46843083, 5.69239793, 5.81938537, 6.24615224, 5.81938537,
#        5.24097019, 6.02616669, 5.52699469, 6.27800106, 5.86157658,
#        5.3737308 , 5.98590674, 5.24097019, 5.27178076, 6.10412732,
#        6.4597379 , 5.44832258, 5.94496795, 5.98590674, 5.4104513 ,
#        5.65036646, 5.903481  , 5.27178076, 5.27178076, 5.60870164,
#        5.3737308 , 6.4597379 , 5.69239793, 5.60870164, 5.77703807,
#        6.24615224, 5.60870164, 5.3737308 , 5.27178076, 5.30426484,
#        5.4104513 , 5.44832258, 5.33829175, 5.903481  , 5.56753415,
#        5.48721393, 5.52699469, 5.15988646, 5.21196383, 6.27800106,
#        5.3737308 , 6.06561711, 5.33829175, 5.60870164, 5.56753415,
#        5.86157658, 5.33829175, 5.94496795, 5.27178076, 6.40876642,
#        5.46764891, 5.33829175, 6.47136298, 5.22623332, 6.14156662,
#        5.27178076, 5.30426484, 5.65036646, 5.69239793, 5.33829175,
#        5.52699469, 6.42830893, 5.65036646, 5.44832258, 5.4104513 ,
#        5.81938537, 5.73466536, 5.903481  , 5.56753415, 5.21196383,
#        5.4104513 , 6.24615224, 5.56753415, 6.10412732, 5.24097019,
#        5.18489236, 5.69239793, 5.21196383, 5.3737308 , 6.42830893,
#        5.86157658, 5.94496795, 5.33829175, 5.81938537, 6.30812555,
#        5.52699469, 5.44832258, 6.42830893, 5.69239793, 5.21196383,
#        5.30426484, 5.52699469, 5.73466536, 5.21196383, 5.21196383,
#        6.4597379 , 5.24097019, 5.81938537])

# %%
y_test
# Out:
# 946    5
# 142    4
# 934    6
# 625    6
# 124    5
#       ..
# 230    6
# 402    5
# 190    8
# 478    6
# 145    7
# Name: quality, Length: 343, dtype: int64

# %%
model.intercept_
# Out:
# 27.779506737364258

# %%
model.coef_
# Out:
# array([-7.03014663,  0.69790271, -0.0217811 ])

# %%
plt.scatter(x_test, y_test)
sns.lineplot(x=x_test.values.reshape(-1,), y=y_pred)
plt.show()

# %%
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 0.4432596624597685
# Root_Mean_Squared_Error: 0.6657774871980642
# Mean_Absolute_Error: 0.5242919408195995

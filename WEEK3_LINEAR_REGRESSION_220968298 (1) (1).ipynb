# %% [markdown]
# ## Name- Shivli Mathur
# ## Reg. no.-220968298
# ## Batch-B4
# ## Week-3

# %% [markdown]
# ### For mtcars dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/HP/Downloads/mtcars.csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
x=df[["mpg"]]
y=df["qsec"]

# %%
x
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
y
# Out:
# 0     16.46
# 1     17.02
# 2     18.61
# 3     19.44
# 4     17.02
# 5     20.22
# 6     15.84
# 7     20.00
# 8     22.90
# 9     18.30
# 10    18.90
# 11    17.40
# 12    17.60
# 13    18.00
# 14    17.98
# 15    17.82
# 16    17.42
# 17    19.47
# 18    18.52
# 19    19.90
# 20    20.01
# 21    16.87
# 22    17.30
# 23    15.41
# 24    17.05
# 25    18.90
# 26    16.70
# 27    16.90
# 28    14.50
# 29    15.50
# 30    14.60
# 31    18.60
# Name: qsec, dtype: float64

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([17.2214961 , 17.04689119, 17.42520184, 18.15272234, 16.97413914,
#        16.34847151, 17.13419364, 18.61833545, 17.96356701, 17.04689119])

# %%
y_test
# Out:
# 11    17.40
# 22    17.30
# 10    18.90
# 2     18.61
# 16    17.42
# 14    17.98
# 28    14.50
# 26    16.70
# 20    20.01
# 13    18.00
# Name: qsec, dtype: float64

# %%
model.intercept_
# Out:
# 14.835228881601203

# %%
model.coef_
# Out:
# array([0.1455041])

# %%
plt.scatter(x_test,y_test)
plt.plot(x , model.predict(x))
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
import math
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 2.1056028773990114
# Root_Mean_Squared_Error: 1.4510695632529171
# Mean_Absolute_Error: 1.1993148790118506

# %% [markdown]
# ### For diabetes dataset

# %%
df = pd.read_csv('C:/Users/HP/Downloads/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["DiabetesPedigreeFunction"] = df["Insulin"].replace(0, pd.NaT)
df["Insulin"] = df["Insulin"].replace(0, pd.NaT)

# %%
x=df[["Insulin"]]
y=df["DiabetesPedigreeFunction"]

# %%
x=x.dropna()
x
# Out:
#     Insulin
# 3        94
# 4       168
# 6        88
# 8       543
# 13      846
# ..      ...
# 753     510
# 755     110
# 760      16
# 763     180
# 765     112
#
# [394 rows x 1 columns]

# %%
y=y.dropna()
y
# Out:
# 3       94
# 4      168
# 6       88
# 8      543
# 13     846
#       ...
# 753    510
# 755    110
# 760     16
# 763    180
# 765    112
# Name: DiabetesPedigreeFunction, Length: 394, dtype: object

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([370.,  76.,  63., 148., 105.,  95.,  92., 130.,  89.,  70.,  51.,
#         57., 215., 112., 205.,  95., 215.,  94., 135., 156.,  46., 180.,
#         94., 105., 185., 110., 155., 158., 278.,  50., 106., 280., 210.,
#         53., 156., 194.,  37., 510.,  56., 230., 168.,  44., 105., 160.,
#        105.,  55., 120., 180.,  44., 478., 325., 146., 110.,  40.,  66.,
#        126., 110.,  84.,  74., 145.,  54.,  41.,  79., 175., 140., 180.,
#         83.,  74.,  82.,  94., 328., 105., 105.,  94.,  58., 375., 140.,
#        100., 330., 170., 360.,  76., 440., 110., 100.,  96., 249.,  29.,
#         63.,  50.,  40.,  71.,  49.,  36., 230., 215.,  78., 231., 130.,
#        277.,  75., 495., 105.,  36.,  52., 144., 171.,  36.,  85., 116.,
#        160., 225., 115., 210.,  58., 155.,  23., 125.,  91.])

# %%
y_test
# Out:
# 231    370
# 544     76
# 142     63
# 311    148
# 640    105
#       ...
# 334     58
# 282    155
# 52      23
# 693    125
# 638     91
# Name: DiabetesPedigreeFunction, Length: 119, dtype: object

# %%
model.intercept_
# Out:
# 2.842170943040401e-14

# %%
model.coef_
# Out:
# array([1.])

# %%
plt.scatter(x_test,y_test)
plt.plot(x , model.predict(x))
plt.show()

# %%
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 6.2589152291888275e-28
# Root_Mean_Squared_Error: 2.50178241044037e-14
# Mean_Absolute_Error: 1.3285357874506075e-14

# %% [markdown]
# ### For winequality-red dataset

# %%
df = pd.read_csv('C:\\Users\\HP\\Downloads\\winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
x=df[["alcohol"]]
y=df["quality"]

# %%
x
# Out:
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1138     11.0
# 1139      9.5
# 1140     10.5
# 1141     11.2
# 1142     10.2
#
# [1143 rows x 1 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([5.36881905, 5.99240003, 5.19560211, 5.64596615, 5.33417566,
#        5.64596615, 5.40346243, 5.81918309, 5.99240003, 5.43810582,
#        5.29953227, 5.99240003, 5.74989631, 5.26488888, 6.13097358,
#        5.19560211, 5.74989631, 5.23024549, 5.19560211, 5.5073926 ,
#        5.54203599, 5.33417566, 5.33417566, 5.33417566, 5.29953227,
#        5.09167194, 5.23024549, 5.81918309, 5.92311325, 5.43810582,
#        5.33417566, 5.57667937, 5.92311325, 5.43810582, 5.36881905,
#        5.7845397 , 5.99240003, 5.47274921, 5.23024549, 5.95775664,
#        5.43810582, 6.23490374, 5.54203599, 5.99240003, 5.40346243,
#        5.29953227, 5.33417566, 5.7845397 , 6.13097358, 6.26954713,
#        5.5073926 , 5.88846987, 5.68060954, 6.20026036, 5.33417566,
#        5.23024549, 5.5073926 , 5.26488888, 5.29953227, 5.92311325,
#        5.74989631, 5.19560211, 5.40346243, 5.43810582, 5.5073926 ,
#        5.29953227, 6.33883391, 5.23024549, 5.61132276, 5.68060954,
# ...

# %%
y_test
# Out:
# 946    5
# 142    4
# 934    6
# 625    6
# 124    5
#       ..
# 230    6
# 402    5
# 190    8
# 478    6
# 145    7
# Name: quality, Length: 343, dtype: int64

# %%
model.intercept_
# Out:
# 2.043053802380708

# %%
model.coef_
# Out:
# array([0.34643388])

# %%
plt.scatter(x_test,y_test)
plt.plot(x , model.predict(x))
plt.show()

# %%
mse=mean_squared_error(y_test,y_pred)
print('Mean_Squared_Error: '+str(mse))
rmse=math.sqrt(mse)
print('Root_Mean_Squared_Error: '+str(rmse) )
mse=mean_absolute_error(y_test,y_pred)
print('Mean_Absolute_Error: '+str(mse))
# Out:
# Mean_Squared_Error: 0.45009797078344954
# Root_Mean_Squared_Error: 0.6708934123863861
# Mean_Absolute_Error: 0.5301960063897103
